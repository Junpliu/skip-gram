# %%
from google.colab import drive
drive.mount('/content/drive')
cd /content/drive/My\ Drive/NLP
# %ls

# %%
# !git config --global user.email "jeepliu@bupt.edu.cn"
# !git config --global user.name "junpliu"

# %%
# !git remote add origin https://github.com/Junpliu/skip-gram.git

# %%
# !git push --set-upstream origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git remote remove origin

# %%
# !git remote add origin https://Junpliu:BYto2016@github.com/Junpliu/skip-gram.git

# %%
# !git push -u origin master
# Out:
# To https://github.com/Junpliu/skip-gram.git
#  ! [rejected]        master -> master (fetch first)
# error: failed to push some refs to 'https://Junpliu:BYto2016@github.com/Junpliu/skip-gram.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git commit -m "first commit!"
# Out:
# [master (root-commit) 63346b3] first commit!
#  5 files changed, 14 insertions(+)
#  create mode 100644 __pycache__/model.cpython-36.pyc
#  create mode 100644 getData.py
#  create mode 100644 model.py
#  create mode 100644 skip-gram.ipynb
#  create mode 100644 text8

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > **main-program**
#
#
#
# ---
#
#
#
# ---

# %%
import model

# %%
with open('text8', 'r') as f:
  data = f.read()
  print(len(data.split()))
with open('text8', 'r') as f:
  data = f.readline()
  print(len(data.split()))
# Out:
# 17005207
# 17005207

# %%
import torch
import torch.nn as nn
bedding = nn.Embedding(5, 3)
print(bedding(torch.LongTensor([1, 3, 4])))
# Out:
# tensor([[-0.1713, -0.8076,  0.4228],
#         [-2.2515,  0.4623, -0.5844],
#         [ 0.1945, -0.5775, -1.2978]], grad_fn=<EmbeddingBackward>)

# %%
print(torch.mul(a,b)[1, 0, 1, :])
# Out:
# tensor([ 0.3301,  0.8610, -1.6970])
